# %%
print('PySpark Version :'+spark.version)

big_list = range(10000)
rdd = sc.parallelize(big_list, 2)
odds = rdd.filter(lambda x: x % 2 != 0)
odds.take(5)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# PySpark Version :2.4.8-amzn-2
# [1, 3, 5, 7, 9]

# %%
sc.install_pypi_package("requests")
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# An error was encountered:
# Package already installed for current Spark context!
# Traceback (most recent call last):
#   File "/usr/lib/spark/python/lib/pyspark.zip/pyspark/context.py", line 1110, in install_pypi_package
#     raise ValueError("Package already installed for current Spark context!")
# ValueError: Package already installed for current Spark context!

# %%
params = {
  'access_key': '5cf29606576465e5ccb8081fb532387b'
}

api_result = requests.get('http://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()

print(api_response)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 410916}, 'data': [{'flight_date': '2023-02-15', 'flight_status': 'scheduled', 'departure': {'airport': None, 'timezone': None, 'iata': 'KBV', 'icao': 'VTSG', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2023-02-15T08:35:00+00:00', 'estimated': '2023-02-15T08:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': None, 'timezone': None, 'iata': 'DMK', 'icao': 'VTBD', 'terminal': '2', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2023-02-15T10:05:00+00:00', 'estimated': '2023-02-15T10:05:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'AirAsia', 'iata': 'AK', 'icao': 'AXM'}, 'flight': {'number': '3228', 'iata': 'AK3228', 'icao': 'AXM3228', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2023-02-15', 'flight_status': 'scheduled', 'departure': {'airport': None, 'timezone': None, 'iata': 'BHS', 'icao': 'YBTH', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2023-02-15T12:50:00+00:00', 'estimated': '2023-02-15T12:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': None, 'timezone': None, 'iata': 'SYD', 'icao': 'YSSY', 'terminal': '2', 'gate': 'AG7', 'baggage': 'D6', 'delay': None, 'scheduled': '2023-02-15T13:40:00+00:00', 'estimated': '2023-02-15T13:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Fly Pro', 'iata': 'FP', 'icao': 'PVV'}, 'flight': {'number': '124', 'iata': 'FP124', 'icao': 'PVV124', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2023-02-15', 'flight_status': 'scheduled', 'departure': {'airport': None, 'timezone': None, 'iata': 'KBR', 'icao': 'WMKC', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2023-02-15T09:55:00+00:00', 'estimated': '2023-02-15T09:55:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': None, 'timezone': None, 'iata': 'SZB', 'icao': 'WMSA', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2023-02-15T11:00:00+00:00', 'estimated': '2023-02-15T11:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Firefly', 'iata': 'FY', 'icao': 'FFM'}, 'flight': {'number': '1155', 'iata': 'FY1155', 'icao': 'FFM1155', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2023-02-15', 'flight_status': 'scheduled', 'departure': {'airport': None, 'timezone': None, 'iata': 'KBR', 'icao': 'WMKC', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2023-02-15T09:55:00+00:00', 'estimated': '2023-02-15T09:55:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': None, 'timezone': None, 'iata': 'SZB', 'icao': 'WMSA', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2023-02-15T11:00:00+00:00', 'estimated': '2023-02-15T11:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'}, 'flight': {'number': '5505', 'iata': 'MH5505', 'icao': 'MAS5505', 'codeshared': {'airline_name': 'firefly', 'airline_iata': 'fy', 'airline_icao': 'ffm', 'flight_number': '1155', 'flight_iata': 'fy1155', 'flight_icao': 'ffm1155'}}, 'aircraft': None, 'live': None}, {'flight_date': '2023-02-15', 'flight_status': 'scheduled', 'departure': {'airport': None, 'timezone': None, 'iata': 'KBR', 'icao': 'WMKC', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2023-02-15T09:40:00+00:00', 'estimated': '2023-02-15T09:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': None, 'timezone': None, 'iata': 'KUL', 'icao': 'WMKK', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2023-02-15T10:50:00+00:00', 'estim ...

# %%
# list all arrival times and count planes in each hour
hours = []
for d in api_response['data']:
#     print(d['arrival']['estimated'])
    hours.append((int(d['arrival']['estimated'][-14:-12]),))
    
cols = ["hour"]
DF = spark.createDataFrame(data=hours, schema = cols)
DF.groupBy("hour").count().sort("hour").show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# list all departure times and count planes in each hour
hours = []
for d in api_response['data']:
#     print(d['departure']['estimated'])
    hours.append((int(d['departure']['estimated'][-14:-12]),))
    
cols = ["hour"]
DF = spark.createDataFrame(data=hours, schema = cols)
DF.groupBy("hour").count().sort("hour").show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +----+-----+
# |hour|count|
# +----+-----+
# |   0|    1|
# |   1|   55|
# |   2|   38|
# |   3|    5|
# |   5|    1|
# +----+-----+
